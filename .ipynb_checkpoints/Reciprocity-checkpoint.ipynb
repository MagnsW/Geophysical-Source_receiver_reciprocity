# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np

# %%
path = './input/'
filename1 = path + '10x50m_Top_D15_+ve.txt'
filename2 = path + '10x50m_Top_D15_-ve.txt'

# %%
f = open(filename2)
lines = f.read().splitlines()
f.close()
for i, line in enumerate(lines):
    if i < 10:
        print(i, line)
# Out:
# 0
# 1 ShotNo  StrNo  RecNo  Offset:m  MidPtX:m  MidPtY:m  DipSrc:°  DipRec:°  AzSrc:°  AzRec:°  Ttime:s  ReflPosX:m  ReflPosY:m  RefAngIn:°  RefAngOut:°
# 2 1       1      241    158.34    5016.67   2000      7.80479   169.135   -89.9996 89.9997  1.85282  4558.24     2000        2.49332     2.49332
# 3 1       1      242    158.832   5016.67   1993.75   7.80576   169.134   -89.0664 89.3274  1.85283  4558.24     1993.82     2.50147     2.50147
# 4 1       1      243    160.301   5016.67   1987.5    7.81143   169.135   -88.1224 88.6464  1.85282  4558.11     1987.56     2.52212     2.52204
# 5 1       1      244    162.72    5016.67   1981.25   7.81817   169.133   -87.188  87.9715  1.85285  4558.03     1981.36     2.55987     2.55987
# 6 1       1      245    166.047   5016.67   1975      7.82517   169.128   -86.2764 87.313   1.85291  4558.03     1975.3      2.61389     2.61382
# 7 1       1      246    170.229   5016.67   1968.75   7.83217   169.12    -85.3648 86.6552  1.85301  4558.11     1969.24     2.68438     2.68438
# 8 1       1      247    175.204   5016.67   1962.5    7.84433   169.113   -84.3982 85.955   1.85311  4558.07     1962.79     2.76916     2.76916
# 9 1       1      248    180.908   5016.67   1956.25   7.8576    169.105   -83.4911 85.2968  1.85322  4558.05     1956.71     2.86122     2.86115

# %%
column_names = ['ShotNo', 'StrNo', 'RecNo', 'Offset', 'MidPtX', 'MidPtY', 'DipSrc', 'DipRec', 'AzSrc', 'AzRec', 'Ttime', 'ReflPosX', 'ReflPosY', 'RefAngIn', 'RefAngOut']

# %%
df1_raw = pd.DataFrame()
df2_raw = pd.DataFrame()

# %%
rowstoskip = 2

# %%
df1_raw = pd.read_csv(filename1, names=column_names, skiprows=rowstoskip, delim_whitespace=True)
df2_raw = pd.read_csv(filename2, names=column_names, skiprows=rowstoskip, delim_whitespace=True)

# %%
df1_raw.plot(x='ReflPosX', y='ReflPosY', figsize=(16, 12), kind='scatter')
plt.title('Positive offsets');

# %%
df2_raw.plot(x='ReflPosX', y='ReflPosY', figsize=(16, 12), kind='scatter')
plt.title('Negative offsets');

# %%
#df1_raw.plot(x='ShotNo', y='RefAngIn', figsize=(16, 12), kind='scatter');

# %%
#test = df1_raw.iloc[[1]]

# %%
#test['Offset']

# %% [markdown]
# ## Setting the limits for Reciprocal traces:

# %%
d_offset = 20
d_reflpoint = 20
d_azm = 30

# %%
def is_resiproc(row1, row2):
    if ((abs(row1['Offset'].values-row2['Offset'].values) < d_offset) & 
        (abs(row1['ReflPosX'].values-row2['ReflPosX'].values) < d_reflpoint) & 
        (abs(row1['ReflPosY'].values-row2['ReflPosY'].values) < d_reflpoint) & 
        (abs(-row1['AzSrc'].values-row2['AzRec'].values) < d_azm) & 
        (abs(-row1['AzRec'].values-row2['AzSrc'].values) < d_azm)):
        #print('Reciproc trace found!')
        return True
    else:
        return False

# %%
from datetime import datetime

# %%
print(len(df1_raw))
# Out:
# 578400

# %% [markdown]
# ## Subselecting only MidPtY = 3500 (full fold) to limit number of datarows in the for-loop:

# %%
df1_mpy_3500 = df1_raw[df1_raw['MidPtY']==3500].reset_index()
df2_mpy_3500 = df2_raw[df2_raw['MidPtY']==3500].reset_index()

# %%
print(len(df2_mpy_3500))
# Out:
# 1200

# %% [markdown]
# ## Making list of Reciproc Traces using for-loop (slow):

# %%
print(datetime.now())
# Out:
# 2019-05-20 15:15:05.718774

# %%
reciproc_list = []
for i in range(len(df1_mpy_3500)):
    for j in range(len(df2_mpy_3500)):
        if(is_resiproc(df1_mpy_3500.iloc[[i]], df2_mpy_3500.iloc[[j]])):
            print('Reciprocal trace found at '+ str(i) + ' ' + str(j))
            reciproc_list.append((i, j))
# Out:
# Reciprocal trace found at 1082 20
# Reciprocal trace found at 1082 50
# Reciprocal trace found at 1083 20
# Reciprocal trace found at 1083 50
# Reciprocal trace found at 1091 50
# Reciprocal trace found at 1092 20
# Reciprocal trace found at 1092 50
# Reciprocal trace found at 1093 51
# Reciprocal trace found at 1096 68
# Reciprocal trace found at 1097 9
# Reciprocal trace found at 1097 39
# Reciprocal trace found at 1097 68
# Reciprocal trace found at 1098 69
# Reciprocal trace found at 1105 8
# Reciprocal trace found at 1105 38
# Reciprocal trace found at 1105 67
# Reciprocal trace found at 1106 8
# Reciprocal trace found at 1106 38
# Reciprocal trace found at 1106 78
# Reciprocal trace found at 1107 49
# Reciprocal trace found at 1107 78
# Reciprocal trace found at 1108 79
# Reciprocal trace found at 1110 90
# Reciprocal trace found at 1111 40
# Reciprocal trace found at 1111 91
# Reciprocal trace found at 1112 10
# Reciprocal trace found at 1112 40
# Reciprocal trace found at 1112 71
# Reciprocal trace found at 1112 92
# Reciprocal trace found at 1113 72
# Reciprocal trace found at 1113 93
# Reciprocal trace found at 1114 21
# Reciprocal trace found at 1114 52
# Reciprocal trace found at 1114 72
# Reciprocal trace found at 1114 94
# Reciprocal trace found at 1115 52
# Reciprocal trace found at 1115 95
# Reciprocal trace found at 1116 96
# Reciprocal trace found at 1117 97
# Reciprocal trace found at 1120 70
# Reciprocal trace found at 1121 71
# Reciprocal trace found at 1122 21
# Reciprocal trace found at 1122 93
# Reciprocal trace found at 1122 94
# Reciprocal trace found at 1123 22
# Reciprocal trace found at 1123 52
# Reciprocal trace found at 1123 94
# Reciprocal trace found at 1124 22
# Reciprocal trace found at 1124 53
# Reciprocal trace found at 1124 66
# Reciprocal trace found at 1125 7
# Reciprocal trace found at 1125 37
# Reciprocal trace found at 1125 53
# Reciprocal trace found at 1125 66
# Reciprocal trace found at 1125 84
# Reciprocal trace found at 1126 37
# Reciprocal trace found at 1126 84
# Reciprocal trace found at 1126 85
# Reciprocal trace found at 1127 8
# Reciprocal trace found at 1127 38
# Reciprocal trace found at 1128 78
# Reciprocal trace found at 1129 79
# Reciprocal trace found at 1130 80
# Reciprocal trace found at 1131 81
# Reciprocal trace found at 1131 102
# Reciprocal trace found at 1132 82
# Reciprocal trace found at 1132 95
# Reciprocal trace found at 1132 103
# Reciprocal trace found at 1132 104
# Reciprocal trace found at 1133 66
# Reciprocal trace found at 1133 83
# Reciprocal trace found at 1133 95
# Reciprocal trace found at 1134 7
# Reciprocal trace found at 1134 37
# Reciprocal trace found at 1134 66
# Reciprocal trace found at 1134 76
# Reciprocal trace found at 1135 7
# Reciprocal trace found at 1135 47
# Reciprocal trace found at 1135 76
# Reciprocal trace found at 1136 18
# Reciprocal trace found at 1136 47
# Reciprocal trace found at 1137 18
# Reciprocal trace found at 1137 48
# Reciprocal trace found at 1139 89
# Reciprocal trace found at 1140 60
# Reciprocal trace found at 1141 61
# Reciprocal trace found at 1142 11
# Reciprocal trace found at 1142 62
# Reciprocal trace found at 1143 42
# Reciprocal trace found at 1143 63
# Reciprocal trace found at 1144 42
# Reciprocal trace found at 1144 64
# Reciprocal trace found at 1145 53
# Reciprocal trace found at 1145 65
# Reciprocal trace found at 1145 73
# Reciprocal trace found at 1145 74
# Reciprocal trace found at 1146 53
# Reciprocal trace found at 1146 66
# Reciprocal trace found at 1146 84
# Reciprocal trace found at 1147 67
# Reciprocal trace found at 1147 105
# Reciprocal trace found at 1147 106
# Reciprocal trace found at 1148 68
# Reciprocal trace found at 1148 107
# Reciprocal trace found at 1148 116
# Reciprocal trace found at 1149 69
# Reciprocal trace found at 1150 40
# Reciprocal trace found at 1150 91
# Reciprocal trace found at 1151 41
# Reciprocal trace found at 1151 92
# Reciprocal trace found at 1151 93
# Reciprocal trace found at 1152 42
# Reciprocal trace found at 1153 64
# Reciprocal trace found at 1154 6
# Reciprocal trace found at 1154 35
# Reciprocal trace found at 1155 6
# Reciprocal trace found at 1156 54
# Reciprocal trace found at 1156 55
# Reciprocal trace found at 1157 47
# Reciprocal trace found at 1158 48
# Reciprocal trace found at 1158 86
# Reciprocal trace found at 1158 87
# Reciprocal trace found at 1159 49
# Reciprocal trace found at 1160 20
# Reciprocal trace found at 1160 50
# Reciprocal trace found at 1160 101
# Reciprocal trace found at 1160 122
# Reciprocal trace found at 1160 123
# Reciprocal trace found at 1161 21
# Reciprocal trace found at 1161 51
# Reciprocal trace found at 1161 102
# Reciprocal trace found at 1161 103
# Reciprocal trace found at 1162 22
# Reciprocal trace found at 1162 52
# Reciprocal trace found at 1162 94
# Reciprocal trace found at 1163 36
# Reciprocal trace found at 1163 53
# Reciprocal trace found at 1163 65
# Reciprocal trace found at 1163 74
# Reciprocal trace found at 1163 75
# Reciprocal trace found at 1164 6
# Reciprocal trace found at 1164 46
# Reciprocal trace found at 1164 54
# Reciprocal trace found at 1165 17
# Reciprocal trace found at 1165 46
# Reciprocal trace found at 1168 58
# Reciprocal trace found at 1169 59
# Reciprocal trace found at 1170 0
# Reciprocal trace found at 1170 30
# Reciprocal trace found at 1171 31
# Reciprocal trace found at 1172 32
# Reciprocal trace found at 1173 33
# Reciprocal trace found at 1174 13
# Reciprocal trace found at 1174 34
# Reciprocal trace found at 1175 35
# Reciprocal trace found at 1175 43
# Reciprocal trace found at 1175 44
# Reciprocal trace found at 1176 6
# Reciprocal trace found at 1176 23
# Reciprocal trace found at 1176 36
# Reciprocal trace found at 1176 54
# Reciprocal trace found at 1176 74
# Reciprocal trace found at 1176 75
# Reciprocal trace found at 1177 7
# Reciprocal trace found at 1177 37
# Reciprocal trace found at 1177 76
# Reciprocal trace found at 1177 84
# Reciprocal trace found at 1177 85
# Reciprocal trace found at 1178 8
# Reciprocal trace found at 1178 38
# Reciprocal trace found at 1178 106
# Reciprocal trace found at 1179 9
# Reciprocal trace found at 1179 39
# Reciprocal trace found at 1179 108
# Reciprocal trace found at 1180 10
# Reciprocal trace found at 1180 40
# Reciprocal trace found at 1180 91
# Reciprocal trace found at 1180 92
# Reciprocal trace found at 1181 11
# Reciprocal trace found at 1181 41
# Reciprocal trace found at 1182 12
# Reciprocal trace found at 1182 63
# Reciprocal trace found at 1183 5
# Reciprocal trace found at 1183 13
# Reciprocal trace found at 1183 34
# Reciprocal trace found at 1186 16
# Reciprocal trace found at 1186 24
# Reciprocal trace found at 1187 17
# Reciprocal trace found at 1187 55
# Reciprocal trace found at 1187 56
# Reciprocal trace found at 1188 18
# Reciprocal trace found at 1188 48
# Reciprocal trace found at 1188 86
# Reciprocal trace found at 1189 19
# Reciprocal trace found at 1189 49
# Reciprocal trace found at 1189 88
# Reciprocal trace found at 1190 20
# Reciprocal trace found at 1190 101
# Reciprocal trace found at 1190 102
# Reciprocal trace found at 1190 122
# Reciprocal trace found at 1190 123
# Reciprocal trace found at 1191 21
# Reciprocal trace found at 1191 93
# Reciprocal trace found at 1191 94
# Reciprocal trace found at 1191 103
# Reciprocal trace found at 1192 22
# Reciprocal trace found at 1192 65
# Reciprocal trace found at 1192 73
# Reciprocal trace found at 1192 74
# Reciprocal trace found at 1193 6
# Reciprocal trace found at 1193 23
# Reciprocal trace found at 1193 36
# Reciprocal trace found at 1194 16
# Reciprocal trace found at 1194 24
# Reciprocal trace found at 1194 45
# Reciprocal trace found at 1195 25
# Reciprocal trace found at 1197 27
# Reciprocal trace found at 1198 28
# Reciprocal trace found at 1199 29

# %%
print(datetime.now())
# Out:
# 2019-05-20 15:15:12.304495

# %%
len(reciproc_list)
# Out:
# 219

# %%
#reciproc_list_noazm = reciproc_list

# %%
#df1_mpy_3500

# %%
df1_mpy_3500['Reciproc'] = False
df2_mpy_3500['Reciproc'] = False

# %%
for k,l in reciproc_list:
    #print(k, l)
    df1_mpy_3500.iloc[k, -1] = True
    df2_mpy_3500.iloc[l, -1] = True
# Out:
# 1082 20
# 1082 50
# 1083 20
# 1197  154.273 -17.0373  15.0863  2.27596   4346.47   3493.89  41.950200
# 1198  154.330 -17.7983  14.1773  2.27225   4323.01   3488.69  42.079700
# 1199  154.384 -18.5542  13.2589  2.26876   4299.34   3483.43  42.217900
#
#       RefAngOut  Reciproc
# 0      2.493320      True
# 1      1.712810     False
# 2      0.925984     False
# 3      0.132704     False
# 4      0.666172     False
# 5      1.471130      True
# 6      2.281220      True
# 7      3.097060      True
# 8      3.925510      True
# 9      4.750070      True
# 10     3.581410      True
# 11     2.808750      True
# 12     2.032690      True
# 13     1.269490      True
# 14     0.576412     False
# 15     0.578446     False
# 16     1.288920      True
# 17     2.073680      True
# 18     2.884250      True
# 19     3.704700      True
# 20     4.703570      True
# 21     3.941290      True
# 22     3.178170      True
# 23     2.419050      True
# 24     1.696970      True
# 25     1.072470      True
# 26     0.848345     False
# 27     1.271030      True
# 28     1.965830      True
# 29     2.739100      True
# ...         ...       ...
# 1170  40.381600     False
# 1171  40.471500     False
# 1172  40.569400     False
# 1173  40.676900     False
# 1174  40.792200     False
# 1175  40.917700     False
# 1176  41.050000     False
# 1177  41.191100     False
# 1178  41.340700     False
# 1179  41.500700     False
# 1180  40.821300     False
# 1181  40.902900     False
# 1182  40.991300     False
# 1183  41.088900     False
# 1184  41.194800     False
# 1185  41.309000     False
# 1186  41.431800     False
# 1187  41.562600     False
# 1188  41.702900     False
# 1189  41.850800     False
# 1190  41.275600     False
# 1191  41.347400     False
# 1192  41.426500     False
# 1193  41.514600     False
# 1194  41.611500     False
# 1195  41.715900     False
# 1196  41.828300     False
# 1197  41.950200     False
# 1198  42.079700     False
# 1199  42.217900     False
#
# [1200 rows x 17 columns]

# %% [markdown]
# ## Plotting data

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(18,12))
sns.regplot(x=df1_mpy_3500['AzSrc'], y=df1_mpy_3500["AzRec"], fit_reg=False, label='Positive offsets')
sns.regplot(x=df2_mpy_3500['AzSrc'], y=df2_mpy_3500["AzRec"], fit_reg=False, label='Negative offsets')
sns.regplot(x=df2_mpy_3500[df2_mpy_3500['Reciproc']]['AzSrc'], y=df2_mpy_3500[df2_mpy_3500['Reciproc']]["AzRec"], fit_reg=False, label='Reciproc negative offsets')
plt.legend();

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(18,12))
sns.regplot(x=df1_mpy_3500['MidPtX'], y=df1_mpy_3500["Offset"], fit_reg=False, label='Positive offsets')
sns.regplot(x=df2_mpy_3500['MidPtX'], y=df2_mpy_3500["Offset"], fit_reg=False, label='Negative offsets')
sns.regplot(x=df2_mpy_3500[df2_mpy_3500['Reciproc']]['MidPtX'], y=df2_mpy_3500[df2_mpy_3500['Reciproc']]["Offset"], fit_reg=False, label='Reciproc negative offsets');
plt.legend();

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(18,12))
sns.regplot(x=df1_mpy_3500['ReflPosX'], y=df1_mpy_3500["Offset"], fit_reg=False, label='Positive offsets')
sns.regplot(x=df2_mpy_3500['ReflPosX'], y=df2_mpy_3500["Offset"], fit_reg=False, label='Negative offsets')
sns.regplot(x=df2_mpy_3500[df2_mpy_3500['Reciproc']]['ReflPosX'], y=df2_mpy_3500[df2_mpy_3500['Reciproc']]["Offset"], fit_reg=False, label='Reciproc negative offsets');
plt.legend();

# %%
plt.figure(figsize=(18,12))
plt.hist(df1_mpy_3500['Offset'], range=(0, 3000), bins=120, alpha=0.6, label='Positive offsets')
plt.hist(df2_mpy_3500['Offset'], range=(0, 3000), bins=120, alpha=0.6, label='Negative offsets')
plt.hist(df2_mpy_3500[df2_mpy_3500['Reciproc']]['Offset'], range=(0, 3000), bins=120, alpha=0.6, label='Reciproc negative offsets')
plt.legend();

# %% [markdown]
# ## Experimental code below (Ignore)

# %%
offset_min = 0
offset_max = int(np.ceil(max(df1_raw.Offset.max(), df2_raw.Offset.max())))
offset_inc = 10

# %%
midptx_min = int(np.floor(min(df1_raw.MidPtX.min(), df2_raw.MidPtX.min())))
midptx_max = int(np.ceil(max(df1_raw.MidPtX.max(), df2_raw.MidPtX.max())))
midpty_min = int(np.floor(min(df1_raw.MidPtY.min(), df2_raw.MidPtY.min())))
midpty_max = int(np.ceil(max(df1_raw.MidPtY.max(), df2_raw.MidPtY.max())))
midpt_inc = 10

# %%
int(offset_max)

# %%
offset_breaks = range(offset_min, offset_max + offset_inc, offset_inc)
offset_planes = pd.IntervalIndex.from_breaks(offset_breaks)

# %%
midptx_breaks = range(midptx_min, midptx_max + midpt_inc, midpt_inc)
midptx_planes = pd.IntervalIndex.from_breaks(midptx_breaks)
midpty_breaks = range(midpty_min, midpty_max + midpt_inc, midpt_inc)
midpty_planes = pd.IntervalIndex.from_breaks(midpty_breaks)

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()

df1 = df1_raw
df2 = df2_raw

# %%
df1['Offset plane'] = pd.cut(df1_raw['Offset'], offset_planes)
df2['Offset plane'] = pd.cut(df2_raw['Offset'], offset_planes)
df1['MidPtX plane'] = pd.cut(df1_raw['MidPtX'], midptx_planes)
df2['MidPtX plane'] = pd.cut(df2_raw['MidPtX'], midptx_planes)
df1['MidPtY plane'] = pd.cut(df1_raw['MidPtY'], midpty_planes)
df2['MidPtY plane'] = pd.cut(df2_raw['MidPtY'], midpty_planes)

# %%
df1

# %%
df2_raw.AzSrc.max()

# %%
df2_raw.AzRec.min()

# %%
len(df1)+len(df2)

# %%
#df_all = df1.merge(df2.drop_duplicates(), on=['Offset plane','MidPtX plane', 'MidPtY plane'], how='left', indicator=True)

# %%
#len(df_all)

# %%
#test = df1[~df1[['Offset planes', 'MidPtX planes', 'MidPtY planes']].isin(df2[['Offset planes', 'MidPtX planes', 'MidPtY planes']])].dropna()

# %%
df1['ve'] = '+'
df2['ve'] = '-'

# %%
df1['Duplicated in self'] = df1.duplicated(subset=['Offset plane','MidPtX plane', 'MidPtY plane'])
df2['Duplicated in self'] = df2.duplicated(subset=['Offset plane','MidPtX plane', 'MidPtY plane'])

# %%
df_concat = pd.concat([df1, df2]).reset_index()

# %%
df_concat['Duplicated'] = df_concat.duplicated(subset=['Offset plane','MidPtX plane', 'MidPtY plane'])

# %%
df_concat

# %%
df_concat.Duplicated.value_counts()

# %%
df1['Duplicated in self'].value_counts()

# %%
df2['Duplicated in self'].value_counts()

# %%
plt.figure(figsize=(12,8))
plt.hist(df_concat['Offset'], bins=40, alpha=0.6, label='all')
plt.hist(df_concat[df_concat['Duplicated']]['Offset'], bins=40, alpha=0.6, label='duplicates');

# %%
plt.figure(figsize=(12,8))
plt.hist(df1['Offset'], bins=40, alpha=0.6, label='all')
plt.hist(df1[df1['Duplicated in self']]['Offset'], bins=40, alpha=0.6, label='non duplicates');

# %%
plt.figure(figsize=(12,8))
plt.hist(df2['Offset'], bins=40, alpha=0.6, label='all')
plt.hist(df2[df2['Duplicated in self']]['Offset'], bins=40, alpha=0.6, label='non duplicates');

# %%
df1_dd = df1.drop_duplicates(subset=['Offset plane','MidPtX plane', 'MidPtY plane'])

# %%
len(df1)

# %%
len(df1_dd)

# %%
df2_dd = df2.drop_duplicates(subset=['Offset plane','MidPtX plane', 'MidPtY plane'])

# %%
len(df2)

# %%
len(df2_dd)

# %%
df_concat_dd = pd.concat([df1_dd, df2_dd]).reset_index()

# %%
df_concat_dd['Duplicated'] = df_concat_dd.duplicated(subset=['Offset plane','MidPtX plane', 'MidPtY plane'])

# %%
plt.figure(figsize=(12,8))
plt.hist(df_concat_dd['Offset'], bins=120, alpha=0.6, label='all')
plt.hist(df_concat_dd[df_concat_dd['Duplicated']]['Offset'], bins=120, alpha=0.6, label='duplicates')
plt.legend()
plt.title('Offset histogram');

# %%
df_concat_dd[df_concat_dd['Duplicated']].plot(x='AzSrc', y='AzRec', kind='scatter', figsize=(12,8));

# %%
df_concat_dd.plot(x='AzSrc', y='AzRec', kind='scatter', figsize=(12,8));

# %%
df_concat.plot(x='AzSrc', y='AzRec', kind='scatter', figsize=(12,8));

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(12,8))
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='+']["AzSrc"], y=df_concat_dd[df_concat_dd['ve']=='+']["AzRec"], fit_reg=False)
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='-']["AzSrc"], y=df_concat_dd[df_concat_dd['ve']=='-']["AzRec"], fit_reg=False);
#sns.regplot(x=df_concat_dd[df_concat_dd['Duplicated']]["AzSrc"], y=df_concat_dd[df_concat_dd['Duplicated']]["AzRec"], fit_reg=False)

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(12,8))
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='+']["AzSrc"], y=df_concat_dd[df_concat_dd['ve']=='+']["AzRec"], fit_reg=False)
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='-']["AzSrc"], y=df_concat_dd[df_concat_dd['ve']=='-']["AzRec"], fit_reg=False)
sns.regplot(x=df_concat_dd[df_concat_dd['Duplicated']]["AzSrc"], y=df_concat_dd[df_concat_dd['Duplicated']]["AzRec"], fit_reg=False);

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(18,12))
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='+']["ReflPosX"], y=df_concat_dd[df_concat_dd['ve']=='+']["ReflPosY"], fit_reg=False)
#sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='-']["ReflPosX"], y=df_concat_dd[df_concat_dd['ve']=='-']["ReflPosY"], fit_reg=False)
#sns.regplot(x=df_concat_dd[df_concat_dd['Duplicated']]["ReflPosX"], y=df_concat_dd[df_concat_dd['Duplicated']]["ReflPosY"], fit_reg=False)
plt.ylim(0, 7000);

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(18,12))
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='+']["ReflPosX"], y=df_concat_dd[df_concat_dd['ve']=='+']["ReflPosY"], fit_reg=False)
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='-']["ReflPosX"], y=df_concat_dd[df_concat_dd['ve']=='-']["ReflPosY"], fit_reg=False)
#sns.regplot(x=df_concat_dd[df_concat_dd['Duplicated']]["ReflPosX"], y=df_concat_dd[df_concat_dd['Duplicated']]["ReflPosY"], fit_reg=False)
plt.ylim(0, 7000);

# %%
sns.set_style("whitegrid")
sns.set_palette("Paired")
plt.figure(figsize=(18,12))
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='+']["ReflPosX"], y=df_concat_dd[df_concat_dd['ve']=='+']["ReflPosY"], fit_reg=False)
sns.regplot(x=df_concat_dd[df_concat_dd['ve']=='-']["ReflPosX"], y=df_concat_dd[df_concat_dd['ve']=='-']["ReflPosY"], fit_reg=False)
sns.regplot(x=df_concat_dd[df_concat_dd['Duplicated']]["ReflPosX"], y=df_concat_dd[df_concat_dd['Duplicated']]["ReflPosY"], fit_reg=False)
plt.ylim(3000, 4000);

# %%
df1_raw

# %%
df1_raw[df1_raw['MidPtY']==3500].count()

# %%
df1_mpy_3500 = df1_raw[df1_raw['MidPtY']==3500]

# %%
df1_mpy_3500
